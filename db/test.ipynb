# %%
from pymongo import MongoClient
import json
from pathlib import Path

# %%
client = MongoClient()
print(client.list_database_names())
db = client["access"]
collection = db["2022"]
for year_dir in Path('/home/pinbo/Documents/Plagiarism-Check/data').glob('*'):
    print('*'*50)
    print('*'*50)
    print('*'*50)
    print("Working on: ", year_dir)
    if year_dir.is_dir():
        for doc in year_dir.glob('*'):
            print('-'*50)
            print("Inserting: ", year_dir, "into DB")
            print("Name:",doc.name)
            with open(doc, "r") as file:
                file_data = json.load(file)
                collection.insert_one(file_data)
client.close()
# Out:
# ['access', 'admin', 'config', 'local']
# **************************************************
# **************************************************
# **************************************************
# Working on:  /home/pinbo/Documents/Plagiarism-Check/data/2022
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973235.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973236.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973237.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973238.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973239.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973241.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973243.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973244.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973245.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973290.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973293.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973294.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973295.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973300.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973304.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973307.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973308.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973309.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973310.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973311.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973312.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973314.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973315.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973316.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9973317.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975279.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975290.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975294.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975297.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975313.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975314.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975317.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975319.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975322.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975326.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975798.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9975799.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9976036.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9976049.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9976053.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9976054.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9976056.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9976057.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9978293.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9978604.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9978612.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9978613.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9978623.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9978631.json
# --------------------------------------------------
# Inserting:  /home/pinbo/Documents/Plagiarism-Check/data/2022 into DB
# Name: 9978635.json
